# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for major events in the evolution of life on Earth
events = {
    "Earth Formation": 4.6e9,
    "First Life": 3.8e9,
    "Photosynthesis": 3.5e9,
    "First Eukaryotes": 2.1e9,
    "Cambrian Explosion": 541e6,
    "First Land Plants": 470e6,
    "First Dinosaurs": 230e6,
    "Cretaceous–Paleogene Extinction Event": 66e6,
    "First Humans": 0.2e6,  # Homo sapiens
}

# Define the four major eons (simplified)
eons = ["Hadean", "Archaean", "Proterozoic", "Phanerozoic"]
eon_boundaries = [4.54e9, 4e9, 2.5e9, 541e6]  # Approximate boundaries

# Create the logarithmic timeline
time_points = list(events.values())
time_points.sort(reverse=True)
min_time = min(time_points)
max_time = max(time_points)

plt.figure(figsize=(12, 8))  # Adjust figure size for better visualization
plt.yscale('log')
plt.xlabel('Time (Years Ago)')
plt.ylabel('Eons')
plt.title('Evolution of Life on Earth (Logarithmic Timeline)')

# Plot the events
for event, time in events.items():
    plt.scatter(time, 0, marker='o', s=50, label=event)  # Place events on y=0 for now
    plt.annotate(event, (time, 0), textcoords="offset points", xytext=(0, 10), ha='center')


# Add eon divisions
for i in range(len(eons)):
    plt.axhline(y=i, color='gray', linestyle='--')
    plt.text(-1e8, i-0.2, eons[i], va='top', ha='right', fontsize=12) # Adjust label position

    if i > 0: # Add a line separating eons
        plt.hlines(i, min(time_points), max(time_points), colors='gray', linestyle='dashed')


plt.gca().invert_xaxis() # Reverse x-axis for "time ago"
plt.xlim(max_time * 1.1, min_time * 0.9)
plt.ylim(-0.5, len(eons) - 0.5)
plt.show()
# Out:
# <ipython-input-6-1c633e05449a>:37: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.scatter(time, 0, marker='o', s=50, label=event)  # Place events on y=0 for now
# <ipython-input-6-1c633e05449a>:43: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.axhline(y=i, color='gray', linestyle='--')
# <ipython-input-6-1c633e05449a>:52: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(-0.5, len(eons) - 0.5)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     553     try:
# --> 554         fh = fp.fileno()
#     555         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1c633e05449a> in <cell line: 0>()
#      51 plt.xlim(max_time * 1.1, min_time * 0.9)
#      52 plt.ylim(-0.5, len(eons) - 0.5)
# ---> 53 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     612     """
#     613     _warn_if_gui_out_of_main_thread()
# --> 614     return _get_backend_mod().show(*args, **kwargs)
#     615
#     616
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     479             *metadata*, including the default 'Software' key.
#     480         """
# --> 481         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     482
#     483     def print_to_buffer(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     428         """
#     429         FigureCanvasAgg.draw(self)
# --> 430         mpl.image.imsave(
#     431             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1632         pil_kwargs.setdefault("format", format)
#    1633         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1634         image.save(fname, **pil_kwargs)
#    1635
#    1636
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2594
#    2595         try:
# -> 2596             save_handler(self, fp, filename)
#    2597         except Exception:
#    2598             if open_fp:
#
# /usr/local/lib/python3.11/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1486         )
#    1487     if single_im:
# -> 1488         ImageFile._save(
#    1489             single_im,
#    1490             cast(IO[bytes], _idat(fp, chunk)),
#
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     556         _encode_tile(im, fp, tile, bufsize, fh)
#     557     except (AttributeError, io.UnsupportedOperation) as exc:
# --> 558         _encode_tile(im, fp, tile, bufsize, None, exc)
#     559     if hasattr(fp, "flush"):
#     560         fp.flush()
#
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     582                     # compress to Python file-compatible object
#     583                     while True:
# --> 584                         errcode, data = encoder.encode(bufsize)[1:]
#     585                         fp.write(data)
#     586                         if errcode:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (prokaryotes)": 3.5e9,
    "Photosynthesis begins": 2.5e9,
    "Eukaryotes appear": 1.8e9,
    "Multicellular life": 600e6,
    "Cambrian explosion": 541e6,
    "First land plants": 470e6,
    "First vertebrates": 360e6,
    "Dinosaurs appear": 230e6,
    "Dinosaurs go extinct": 66e6,
    "Mammals dominate": 65e6,
    "Early hominins": 6e6,
    "Modern humans": 300e3,
}

# Prepare data for plotting
event_names = list(events.keys())
event_times = np.array(list(events.values()))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the events on a logarithmic scale
ax.scatter(event_times, range(len(event_times)), color="blue", zorder=5)
ax.hlines(range(len(event_times)), xmin=event_times.min(), xmax=event_times, color="gray", linestyle="dotted", zorder=1)

# Set the y-axis labels
ax.set_yticks(range(len(event_times)))
ax.set_yticklabels(event_names)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (prokaryotes)": 3.5e9,
    "Photosynthesis begins": 2.5e9,
    "Eukaryotes appear": 1.8e9,
    "Multicellular life": 600e6,
    "Cambrian explosion": 541e6,
    "First land plants": 470e6,
    "First vertebrates": 360e6,
    "Dinosaurs appear": 230e6,
    "Dinosaurs go extinct": 66e6,
    "Mammals dominate": 65e6,
    "Early hominins": 6e6,
    "Modern humans": 300e3,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
event_names = list(events.keys())
event_times = np.array(list(events.values()))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the events on a logarithmic scale
ax.scatter(event_times, range(len(event_times)), color="blue", zorder=5)
ax.hlines(range(len(event_times)), xmin=event_times.min(), xmax=event_times, color="gray", linestyle="dotted", zorder=1)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the y-axis labels
ax.set_yticks(range(len(event_times)))
ax.set_yticklabels(event_names)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Eons and Eras)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (prokaryotes)": 3.5e9,
    "Photosynthesis begins": 2.5e9,
    "Eukaryotes appear": 1.8e9,
    "Multicellular life": 600e6,
    "Cambrian explosion": 541e6,
    "First land plants": 470e6,
    "First vertebrates": 360e6,
    "Dinosaurs appear": 230e6,
    "Dinosaurs go extinct": 66e6,
    "Mammals dominate": 65e6,
    "Early hominins": 6e6,
    "Modern humans": 300e3,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
event_names = list(events.keys())
event_times = np.array(list(events.values()))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the events on a logarithmic scale
ax.scatter(event_times, [0]*len(event_times), color="blue", zorder=5)

# Add inline labels for each event
for name, time in events.items():
    ax.text(time, 0, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color="black")

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Remove y-axis since labels are inline
ax.yaxis.set_visible(False)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Inline Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(12, 8))

# Plot the events on a logarithmic scale
for name, time in events.items():
    if name in major_events:
        ax.scatter(time, 0, color="red", s=100, zorder=5, label="Major event" if name == major_events[0] else None)
    else:
        ax.scatter(time, 0, color="blue", zorder=5, label="Other event" if name == "Earth forms" else None)

# Add inline labels for each event
for name, time in events.items():
    color = "red" if name in major_events else "black"
    ax.text(time, 0, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Remove y-axis since labels are inline
ax.yaxis.set_visible(False)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Major Events Highlighted)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Plot the events on a logarithmic scale
for name, time in events.items():
    if name in major_events:
        ax.scatter(time, 0, color="red", s=100, zorder=5, label="Major event" if name == major_events[0] else None)
    else:
        ax.scatter(time, 0, color="blue", zorder=5, label="Other event" if name == "Earth forms" else None)

# Adjust inline labels dynamically to reduce overlap
for i, (name, time) in enumerate(events.items()):
    y_offset = (i % 3 - 1) * 0.5  # Alternate vertical offsets (-0.5, 0, 0.5)
    color = "red" if name in major_events else "black"
    ax.text(time, y_offset, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Remove y-axis since labels are inline
ax.yaxis.set_visible(False)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-3-46d943550af8>:84: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Adjust inline labels dynamically with vertical spacing
y_positions = np.linspace(-2, 2, len(events))  # Create vertical positions

for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions to fill the entire plot space
event_count = len(events)
y_positions = np.linspace(-5, 5, event_count)  # Spread labels across the vertical space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="left", rotation=45, color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Invert the x-axis so that the timeline runs from past to present
ax.invert_xaxis()

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos, f" {name}", fontsize=9, verticalalignment="center", horizontalalignment="center", color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(min(event_times) / 1.1, max(event_times) * 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.03, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="center", color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Flip the x-axis to make it chronological from older to newer
# ax.invert_xaxis()

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Assign y-axis positions based on eons and eras
y_positions = {}
current_y = 0.0
increment = 0.2  # Vertical space for each eon or era

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):
        y_positions[eon] = (current_y, current_y + increment)
        current_y += increment
    else:
        for era, era_bounds in bounds.items():
            y_positions[era] = (current_y, current_y + increment / 3)
            current_y += increment / 3

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Plot the events on a logarithmic scale
for name, time in events.items():
    # Determine y-position based on eon or era
    for category, bounds in {**categories, **categories.get("Phanerozoic", {})}.items():
        if isinstance(bounds, tuple):
            if bounds[0] >= time > bounds[1]:
                y_min, y_max = y_positions[category]
                y_pos = (y_min + y_max) / 2
                break

    color = "red" if name in ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"] else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if color == "red" else 50, zorder=5)
    ax.text(time, y_pos - 0.03, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="center", color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        y_min, y_max = y_positions[eon]
        ax.axhspan(y_min, y_max, color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            y_min, y_max = y_positions[era]
            ax.axhspan(y_min, y_max, color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Flip the x-axis to make it chronological from older to newer
ax.invert_xaxis()

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, current_y + 0.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_ylabel("Eons and Eras")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline by Eons and Eras)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Assign y-axis positions based on eons and eras using logarithmic scaling
def log_scale(start, end):
    return np.logspace(np.log10(start), np.log10(end), num=100)

y_positions = {}
current_y = 0.0
increment = 1.0  # Vertical space for each eon or era (logarithmic scale multiplier)

def calculate_midpoint(start, end):
    return (np.log10(start) + np.log10(end)) / 2

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):
        y_positions[eon] = calculate_midpoint(bounds[0], bounds[1])
    else:
        for era, era_bounds in bounds.items():
            y_positions[era] = calculate_midpoint(era_bounds[0], era_bounds[1])

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Plot the events on a logarithmic scale
for name, time in events.items():
    # Determine y-position based on eon or era
    for category, bounds in {**categories, **categories.get("Phanerozoic", {})}.items():
        if isinstance(bounds, tuple):
            if bounds[0] >= time > bounds[1]:
                y_pos = y_positions[category]
                break

    color = "red" if name in ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"] else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if color == "red" else 50, zorder=5)
    ax.text(time, y_pos - 0.03, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="center", color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        y_pos = y_positions[eon]
        ax.axhline(y=y_pos, color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            y_pos = y_positions[era]
            ax.axhline(y=y_pos, color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Flip the x-axis to make it chronological from older to newer
ax.invert_xaxis()

# Adjust y-axis limits to match the logarithmic scaling
ax.set_yscale("log")
ax.set_ylim(1e0, 5e9)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_ylabel("Eons and Eras (Logarithmic Scale)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline by Eons and Eras)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-13-c0f7ff058e58>:48: RuntimeWarning: divide by zero encountered in log10
#   return (np.log10(start) + np.log10(end)) / 2
# <ipython-input-13-c0f7ff058e58>:107: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 1e3),
    },
}

# Assign y-axis positions based on eons and eras using logarithmic scaling
def calculate_midpoint(start, end):
    return (np.log10(start) + np.log10(end)) / 2

y_positions = {}
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):
        y_positions[eon] = calculate_midpoint(bounds[0], bounds[1])
    else:
        for era, era_bounds in bounds.items():
            y_positions[era] = calculate_midpoint(era_bounds[0], era_bounds[1])

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Plot the events on a logarithmic scale
for name, time in events.items():
    for category, bounds in {**categories, **categories.get("Phanerozoic", {})}.items():
        if isinstance(bounds, tuple):
            if bounds[0] >= time > bounds[1]:
                y_pos = 10**y_positions[category]
                break

    color = "red" if name in ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"] else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if color == "red" else 50, zorder=5)
    ax.text(time, y_pos * 0.9, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="center", color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):
        y_pos = 10**y_positions[eon]
        ax.axhline(y=y_pos, color="lightblue", alpha=0.3, label=eon)
    else:
        for era, era_bounds in bounds.items():
            y_pos = 10**y_positions[era]
            ax.axhline(y=y_pos, color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits tightly to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)

# Flip the x-axis to make it chronological from older to newer
ax.invert_xaxis()

# Adjust y-axis limits to avoid unused space
ax.set_yscale("log")
y_min = min(10**v for v in y_positions.values()) * 0.9
y_max = max(10**v for v in y_positions.values()) * 1.1
ax.set_ylim(y_min, y_max)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_ylabel("Eons and Eras (Logarithmic Scale)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline by Eons and Eras)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First terrestrial plants": 470e6,
    "First land animals": 500e6,
    "First flowers": 130e6,
    "First reptiles": 310e6,
    "First birds": 150e6,
    "First mammals": 200e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Formation of Pangea": 335e6,
    "Cambrian explosion": 541e6,
    "Great Oxidation Event": 2.5e9,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

fig, ax = plt.subplots(figsize=(16, 6))  # Increased width for better spacing

# Plot the events on a logarithmic scale
for name, time in events.items():
    color = "red" if name in ["Cambrian explosion", "Great Oxidation Event", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"] else "blue"
    ax.scatter(time, 1, color=color, s=100 if color == "red" else 50, zorder=5)
    ax.text(time, 0.95, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="center", color=color)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits tightly to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)

# Flip the x-axis to make it chronological from older to newer
ax.invert_xaxis()

# Remove y-axis and ticks for cleaner presentation
ax.get_yaxis().set_visible(False)
ax.set_yticks([])

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Great Oxidation Event": 2.5e9,
    "Cambrian explosion": 541e6,
    "Formation of Pangea": 335e6,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Great Oxidation Event", "Cambrian explosion", "Formation of Pangea", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Great Oxidation Event": 2.5e9,
    "Cambrian explosion": 541e6,
    "Formation of Pangea": 335e6,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Great Oxidation Event", "Cambrian explosion", "Formation of Pangea", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add dotted vertical lines for major events
    if name in major_events:
        ax.vlines(time, ymin=-0.05, ymax=y_pos, colors="red", linestyles="dotted", linewidth=1)

# Highlight eons and eras
for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        ax.axvspan(bounds[1], bounds[0], color="lightblue", alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Great Oxidation Event": 2.5e9,
    "Cambrian explosion": 541e6,
    "Formation of Pangea": 335e6,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Great Oxidation Event", "Cambrian explosion", "Formation of Pangea", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add dotted vertical lines for major events
    if name in major_events:
        ax.vlines(time, ymin=-0.05, ymax=y_pos, colors="red", linestyles="dotted", linewidth=1)

# Highlight eons and eras
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Great Oxidation Event": 2.5e9,
    "Cambrian explosion": 541e6,
    "Formation of Pangea": 335e6,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Great Oxidation Event", "Cambrian explosion", "Formation of Pangea", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add vertical lines from top to bottom for major events
    if name in major_events:
        ax.vlines(time, ymin=0, ymax=1, colors="red", linestyles="dotted", linewidth=1)

# Highlight eons and eras
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Set x-axis tick parameters to improve readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))  # Format ticks with commas
ax.xaxis.set_major_locator(plt.LogLocator(base=10.0, subs=np.arange(1.0, 10.1, 1.0), numticks=10))  # Log scale with nice ticks

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "Great Oxidation Event": 2.5e9,
    "Cambrian explosion": 541e6,
    "Formation of Pangea": 335e6,
    "Permian-Triassic extinction event": 252e6,
    "Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["Great Oxidation Event", "Cambrian explosion", "Formation of Pangea", "Permian-Triassic extinction event", "Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# Dynamically assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot the events on a logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    ax.scatter(time, y_pos, color=color, s=100 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name}", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add vertical lines from top to bottom for major events
    if name in major_events:
        ax.vlines(time, ymin=0, ymax=1, colors="red", linestyles="dotted", linewidth=1)

# Highlight eons and eras
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Set x-axis tick parameters to improve readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'$10^{{{int(np.log10(x))}}}$'))  # Format ticks as powers of 10

# Set x-axis ticks to fixed powers of 10 (e.g., 10^3, 10^6, 10^9)
ax.set_xticks([10**i for i in range(int(np.log10(min(event_times))), int(np.log10(max(event_times))) + 1)])

# Add labels and title
ax.set_xlabel("Time (years ago)")
ax.set_title("Evolution of Life on Earth (Logarithmic Timeline with Adjusted Labels)")

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "  Great Oxidation Event": 2.5e9,
    "  Cambrian explosion": 541e6,
    "  Formation of Pangea": 335e6,
    "  Permian-Triassic extinction event": 252e6,
    "  Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["  Great Oxidation Event", "  Cambrian explosion", "  Formation of Pangea", "  Permian-Triassic extinction event", "  Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot events on logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "darkblue"
    # Format the time as a power of 10 (e.g., 300e3)
    time_str = f"{time:.0e}".replace('e+0', 'e')  # Remove unnecessary '+0' in scientific notation
    ax.scatter(time, y_pos, color=color, s=75 if name in major_events else 50, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name} ({time_str})", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add vertical lines from top to bottom for major events
    if name in major_events:
        ax.vlines(time, ymin= -0.1, ymax=1.1, colors="red", linestyles="dotted", linewidth=2)




# (other) eons
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Set x-axis tick parameters to improve readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'$10^{{{int(np.log10(x))}}}$'))  # Format ticks as powers of 10

# Set x-axis ticks to fixed powers of 10 (e.g., 10^3, 10^6, 10^9)
ax.set_xticks([10**i for i in range(int(np.log10(min(event_times))), int(np.log10(max(event_times))) + 1)])

# Set minor ticks at regular intervals between the major ticks (1, 2, 3, ..., 9 between each power of 10)
ax.minorticks_on()
ax.xaxis.set_minor_locator(plt.LogLocator(base=10.0, subs=np.arange(1.0, 10.1, 1.0), numticks=10))  # Evenly spaced minor ticks

# Add labels and title
ax.set_xlabel("(Logarithmic) Time (years ago)")
ax.set_title("Evolution of Life on Earth Through Eons and Eras — By Evan Maupin | Q4 Bio LK")
ax.set_ylabel("Normalized vertical space (no function)")
# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "  Great Oxidation Event": 2.5e9,
    "  Cambrian explosion": 541e6,
    "  Formation of Pangea": 335e6,
    "  Permian-Triassic extinction event": 252e6,
    "  Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["  Great Oxidation Event", "  Cambrian explosion", "  Formation of Pangea", "  Permian-Triassic extinction event", "  Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot events on logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "darkblue"
    # Format the time as a power of 10 (e.g., 300e3)
    time_str = f"{time:.0e}".replace('e+0', 'e')  # Remove unnecessary '+0' in scientific notation
    ax.scatter(time, y_pos, color=color, s=0)  # Hide the default scatter markers
    marker = "x" if name in major_events else "+"
    ax.plot(time, y_pos, color=color, marker=marker, markersize=10 if name in major_events else 7, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name} ({time_str})", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add vertical lines from top to bottom for major events
    if name in major_events:
        ax.vlines(time, ymin=-0.1, ymax=1.1, colors="red", linestyles="dotted", linewidth=2)

# (other) eons
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Set x-axis tick parameters to improve readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'$10^{{{int(np.log10(x))}}}$'))  # Format ticks as powers of 10

# Set x-axis ticks to fixed powers of 10 (e.g., 10^3, 10^6, 10^9)
ax.set_xticks([10**i for i in range(int(np.log10(min(event_times))), int(np.log10(max(event_times))) + 1)])

# Add labels and title
ax.set_xlabel("(Logarithmic) Time (years ago)")
ax.set_title("Evolution of Life on Earth Through Eons and Eras — By Evan Maupin | Q4 Bio LK")
ax.set_ylabel("Normalized vertical space (no function)")
# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "  Great Oxidation Event": 2.5e9,
    "  Cambrian explosion": 541e6,
    "  Formation of Pangea": 335e6,
    "  Permian-Triassic extinction event": 252e6,
    "  Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

# Prepare data for plotting
major_events = ["  Great Oxidation Event", "  Cambrian explosion", "  Formation of Pangea", "  Permian-Triassic extinction event", "  Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot events on logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    # Format the time as a power of 10 (e.g., 300e3)
    time_str = f"{time:.0e}".replace('e+0', 'e')  # Remove unnecessary '+0' in scientific notation
    marker = "o" if name in major_events else "D"  # Circles for major events, diamonds for others
    ax.scatter(time, y_pos, color=color, marker=marker, s=75 if name in major_events else 30, zorder=5)
    ax.text(time, y_pos - 0.013, f"{name} ({time_str})", fontsize=9, verticalalignment="top", horizontalalignment="left", color=color)

    # Add vertical lines from top to bottom for major events
    if name in major_events:
        ax.vlines(time, ymin=-0.1, ymax=1.1, colors="red", linestyles="dotted", linewidth=2)


# (other) eons
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(era_bounds[1], era_bounds[0], color="lightgreen" if era == "Cenozoic" else "lightcoral" if era == "Mesozoic" else "lightyellow", alpha=0.3, label=era)

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper left")

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Set x-axis tick parameters to improve readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'$10^{{{int(np.log10(x))}}}$'))  # Format ticks as powers of 10

# Set x-axis ticks to fixed powers of 10 (e.g., 10^3, 10^6, 10^9)
ax.set_xticks([10**i for i in range(int(np.log10(min(event_times))), int(np.log10(max(event_times))) + 1)])

# Add labels and title
ax.set_xlabel("(Logarithmic) Time (years ago)")
ax.set_title("Evolution of Life on Earth Through Eons and Eras — By Evan Maupin | Q4 Bio LK")
ax.set_ylabel("Normalized vertical space (no function)")
# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define key events in Earth's history (years ago)
events = {
    "Earth forms": 4.6e9,
    "First life (unicellular)": 3.5e9,
    "First eukaryotic cell": 2.1e9,
    "First multicellular organisms": 1.2e9,
    "First vertebrates": 525e6,
    "First land animals": 500e6,
    "First terrestrial plants": 470e6,
    "First reptiles": 310e6,
    "First mammals": 200e6,
    "First birds": 150e6,
    "First flowers": 130e6,
    "First primates": 55e6,
    "First hominids": 6e6,
    "Modern humans": 300e3,
    "  Great Oxidation Event": 2.5e9,
    "  Cambrian explosion": 541e6,
    "  Formation of Pangea": 335e6,
    "  Permian-Triassic extinction event": 252e6,
    "  Cretaceous-Paleogene extinction event": 66e6,
}

# Define categories (Eons and Eras within the Phanerozoic Eon)
categories = {
    "Hadean": (4.6e9, 4.0e9),
    "Archean": (4.0e9, 2.5e9),
    "Proterozoic": (2.5e9, 541e6),
    "Phanerozoic": {
        "Paleozoic": (541e6, 252e6),
        "Mesozoic": (252e6, 66e6),
        "Cenozoic": (66e6, 0),
    },
}

major_events = ["  Great Oxidation Event", "  Cambrian explosion", "  Formation of Pangea", "  Permian-Triassic extinction event", "  Cretaceous-Paleogene extinction event"]

fig, ax = plt.subplots(figsize=(16, 10))  # Increased width for better spacing

# assign vertical positions
event_count = len(events)
y_positions = np.linspace(0, 1, event_count)  # Use normalized vertical positions to fill space

# Plot events on logarithmic scale
for i, (name, time) in enumerate(events.items()):
    y_pos = y_positions[i]
    color = "red" if name in major_events else "blue"
    # Format the time as a power of 10 (e.g., 300e3)
    time_str = f"{time:.0e}".replace('e+0', 'e')  # Remove unnecessary '+0' in scientific notation
    marker = "o" if name in major_events else "D"  # Circles for major events, diamonds for others

    ax.scatter(
        time,
        y_pos,
        color=color,
        marker=marker,
        s=75 if name in major_events else 30,
        label='Major Events' if name in major_events else 'Milestones',
        zorder=5
        )

    ax.text(
        time,
        y_pos - 0.013,
        f"{name} ({time_str})",
        fontsize=9,
        verticalalignment="top",
        horizontalalignment="left",
        color=color
        )

    # Add vertical lines from top to bottom for major events
    if name in major_events:
        ax.vlines(time, ymin=-0.1, ymax=1.1, colors="red", linestyles="dotted", linewidth=2)

# (other) eons
eon_colors = {
    "Hadean": "#A9C6E8",  # Light blue
    "Archean": "#6B9AC4",  # Medium blue
    "Proterozoic": "#3C7D99",  # Dark blue
}

for eon, bounds in categories.items():
    if isinstance(bounds, tuple):  # Eon without subdivisions
        color = eon_colors.get(eon, "lightblue")  # Use assigned color for first three eons
        ax.axvspan(bounds[1], bounds[0], color=color, alpha=0.3, label=eon)
    else:  # Eon with subdivisions (Phanerozoic)
        for era, era_bounds in bounds.items():
            ax.axvspan(
                era_bounds[1],
                era_bounds[0],
                color="lightgreen" if era == "Cenozoic" else "coral" if era == "Mesozoic" else "yellow",
                alpha=0.3,
                label=era
                )

# Remove duplicate labels in legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), loc="upper right", fancybox=True, shadow=True)

# Set the x-axis to logarithmic scale
ax.set_xscale("log")

# Set x-axis limits to match the range of events
event_times = list(events.values())
ax.set_xlim(max(event_times) * 1.1, min(event_times) / 1.1)  # Add small buffer around the range

# Adjust y-axis limits to fill the vertical space
ax.set_ylim(-0.05, 1.05)

# Add gridlines for major x-ticks to improve readability
ax.grid(visible=True, which="major", axis="x", linestyle="--", color="gray", alpha=0.7)

# Set x-axis tick parameters to improve readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'$10^{{{int(np.log10(x))}}}$'))  # Format ticks as powers of 10
ax.xaxis.minorticks_off()

# Set x-axis ticks to fixed powers of 10 (e.g., 10^3, 10^6, 10^9)
ax.set_xticks([10**i for i in range(int(np.log10(min(event_times))), int(np.log10(max(event_times))) + 1)])

# Add labels and title
ax.set_xlabel("(Logarithmic) Time (years ago)", fontsize=11)
ax.set_title("Evolution of Life on Earth (Logarithmic Scale) — By Evan Maupin | Q4 Bio LK", fontsize=16, weight='medium')
ax.set_ylabel("Normalized vertical space (no function)", fontsize=11)

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()
